# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajaanthonysamy/pyspark/blob/main/01_pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark

# %%
import pandas as pd
import random

# Generate sample data
data = {
    'username': [f'user_{i+1}' for i in range(5)],
    'age': [random.randint(18, 60) for _ in range(5)]
}

df = pd.DataFrame(data)

# Save to CSV
csv_filename = 'user_data.csv'
df.to_csv(csv_filename, index=False)

print(f"Dataset saved to {csv_filename}")
print(df)
# Out:
# Dataset saved to user_data.csv
#   username  age
# 0   user_1   42
# 1   user_2   52
# 2   user_3   59
# 3   user_4   51
# 4   user_5   32

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('Practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5d5c83201787:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('user_data.csv',header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +--------+---+
# |username|age|
# +--------+---+
# |  user_1| 42|
# |  user_2| 52|
# |  user_3| 59|
# |  user_4| 51|
# |  user_5| 32|
# +--------+---+

# %%
df_pyspark.show()
# Out:
# +--------+---+
# |     _c0|_c1|
# +--------+---+
# |username|age|
# |  user_1| 42|
# |  user_2| 52|
# |  user_3| 59|
# |  user_4| 51|
# |  user_5| 32|
# +--------+---+

# %%
df_pysprk = spark.read.option('header','true').csv('user_data.csv')
df_pyspark.show()
# Out:
# +--------+---+
# |username|age|
# +--------+---+
# |  user_1| 42|
# |  user_2| 52|
# |  user_3| 59|
# |  user_4| 51|
# |  user_5| 32|
# +--------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.head(2)
# Out:
# [Row(username='user_1', age=42), Row(username='user_2', age=52)]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- username: string (nullable = true)
#  |-- age: integer (nullable = true)

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
from pyspark.sql import SparkSession

second_spark = SparkSession.builder.appName("df_practise").getOrCreate()

# %%
second_spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5d5c83201787:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = second_spark.read.option("headeer","true").csv("user_data.csv",inferSchema=True)

# %%
df.summary()
# Out:
# DataFrame[summary: string, _c0: string, _c1: string]

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)

# %%
df.describe()
# Out:
# DataFrame[summary: string, _c0: string, _c1: string]
